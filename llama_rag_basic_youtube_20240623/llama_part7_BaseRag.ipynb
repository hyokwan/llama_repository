# %% [markdown]
# ### Install Library

# %%
pip install huggingface_hub==0.23.4 langchain==0.2.5 langchain_community==0.2.5 torch==2.3.0+cu121 transformers==4.40.1 pypdf==4.2.0
# Out:
# Requirement already satisfied: huggingface_hub==0.23.4 in /usr/local/lib/python3.10/dist-packages (0.23.4)
# Collecting langchain==0.2.5
#   Downloading langchain-0.2.5-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 17.9 MB/s eta 0:00:00
# Collecting langchain_community==0.2.5
#   Downloading langchain_community-0.2.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 72.7 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.3.0+cu121 in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Collecting transformers==4.40.1
#   Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 100.3 MB/s eta 0:00:00
# Collecting pypdf==4.2.0
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub==0.23.4) (4.12.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.7 (from langchain==0.2.5)
#   Downloading langchain_core-0.2.9-py3-none-any.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 34.8 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.5)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.5)
#   Downloading langsmith-0.1.81-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (2.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (8.4.1)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community==0.2.5)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0+cu121)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0+cu121)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0+cu121)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0+cu121)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0+cu121)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0+cu121)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0+cu121)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0+cu121)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0+cu121)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0+cu121)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0+cu121)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0+cu121) (2.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.40.1) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.40.1) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.40.1) (0.4.3)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0+cu121)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 72.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.5)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.5)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.7->langchain==0.2.5)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain==0.2.5)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.2.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.2.5) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.23.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.23.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.23.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub==0.23.4) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.5) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0+cu121) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0+cu121) (1.3.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain==0.2.5)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.5)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pypdf, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, jsonpointer, typing-inspect, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jsonpatch, nvidia-cusolver-cu12, langsmith, dataclasses-json, transformers, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed dataclasses-json-0.6.7 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.5 langchain-core-0.2.9 langchain-text-splitters-0.2.1 langchain_community-0.2.5 langsmith-0.1.81 marshmallow-3.21.3 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 orjson-3.10.5 pypdf-4.2.0 transformers-4.40.1 typing-inspect-0.9.0

# %%
# !pip install  nest-asyncio pyngrok

# %%
pip install sentence-transformers==3.0.1 chromadb==0.5.3
# Out:
# Collecting sentence-transformers==3.0.1
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 6.7 MB/s eta 0:00:00
# Collecting chromadb==0.5.3
#   Downloading chromadb-0.5.3-py3-none-any.whl (559 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (4.40.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==3.0.1) (9.4.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (2.7.4)
# Collecting chroma-hnswlib==0.7.3 (from chromadb==0.5.3)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 72.1 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb==0.5.3)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.4 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb==0.5.3)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 10.3 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb==0.5.3)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb==0.5.3)
#   Downloading onnxruntime-1.18.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 102.3 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb==0.5.3)
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 10.7 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb==0.5.3)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb==0.5.3)
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb==0.5.3)
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb==0.5.3)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb==0.5.3)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb==0.5.3)
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (0.12.3)
# Collecting kubernetes>=28.1.0 (from chromadb==0.5.3)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 76.3 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (8.4.1)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb==0.5.3)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.5.3) (3.10.5)
# Collecting httpx>=0.27.0 (from chromadb==0.5.3)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb==0.5.3) (24.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb==0.5.3) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb==0.5.3) (2.0.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.5 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb==0.5.3) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.2 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb==0.5.3) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb==0.5.3) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.27.0->chromadb==0.5.3)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb==0.5.3) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb==0.5.3) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.27.0->chromadb==0.5.3)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2023.6.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb==0.5.3) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb==0.5.3)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.5.3) (1.12.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb==0.5.3)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.3) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3) (1.63.1)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.3)
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 9.3 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3)
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3)
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3)
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 20.7 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3)
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.3)
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.5.3)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.5.3)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.5.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.5.3) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.5.3) (3.3.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers==3.0.1) (12.5.40)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (0.4.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.3) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.3) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb==0.5.3) (13.7.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb==0.5.3)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 40.4 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.5.3)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.5.3)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 89.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.5.3)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.2 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.5.3)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==3.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==3.0.1) (3.5.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb==0.5.3)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.3) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb==0.5.3) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb==0.5.3) (1.2.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.3)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.3) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.3) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.3) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=94ddc59499ffdb706eb703d6f77905d93bd287a6d6b8a4240fd9f3d2f6b58aac
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, ujson, python-multipart, python-dotenv, overrides, opentelemetry-util-http, opentelemetry-proto, humanfriendly, httptools, h11, dnspython, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, httpcore, email_validator, coloredlogs, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, httpx, opentelemetry-sdk, opentelemetry-instrumentation-asgi, fastapi-cli, sentence-transformers, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, fastapi, chromadb
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.3 chroma-hnswlib-0.7.3 chromadb-0.5.3 coloredlogs-15.0.1 deprecated-1.2.14 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 kubernetes-30.1.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.18.0 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 overrides-7.7.0 posthog-3.5.0 pypika-0.48.9 python-dotenv-1.0.1 python-multipart-0.0.9 sentence-transformers-3.0.1 starlette-0.37.2 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0

# %%
# 파일 및 정규표현식 관련 모듈
import os  # 운영 체제와 상호작용하기 위한 모듈
import re  # 정규 표현식을 사용하기 위한 모듈

# PyTorch 관련 모듈
import torch  # PyTorch 프레임워크

# Transformers 관련 모듈
from transformers import (
    AutoModelForCausalLM,  # 언어 모델을 로드하는 함수
    AutoTokenizer,  # 토크나이저를 로드하는 함수
    BitsAndBytesConfig,  # 양자화 및 압축을 위한 설정
    TrainingArguments,  # 모델 훈련을 위한 인자 설정
    pipeline,  # 파이프라인을 생성하는 함수
    logging,  # 로깅을 위한 함수
    AutoConfig,  # 설정을 로드하는 함수
    GenerationConfig  # 텍스트 생성을 위한 설정
)

# Langchain 관련 모듈
from langchain_community.document_loaders import PyPDFLoader  # PDF 문서 로더
from langchain.text_splitter import RecursiveCharacterTextSplitter  # 텍스트 분할기
from langchain.embeddings import HuggingFaceEmbeddings  # 임베딩 생성기
from langchain.schema import Document  # 문서 스키마
from langchain_community.vectorstores import Chroma  # 벡터 저장소
from langchain.chains.question_answering import load_qa_chain  # 질의 응답 체인 로드
from langchain.chains import RetrievalQA, RetrievalQAWithSourcesChain  # 질의 응답 체인
from langchain.memory import ConversationSummaryMemory  # Langchain 메모리 관련 모듈대화 요약 메모리
from langchain.text_splitter import CharacterTextSplitter  # Langchain 텍스트 분할기 모듈 문자 기반 텍스트 분할기
from langchain.prompts import PromptTemplate  # Langchain 프롬프트 템플릿 관련 모듈 프롬프트 템플릿
from langchain.llms import HuggingFacePipeline  # Langchain LLM 관련 모듈 HuggingFace 파이프라인을 사용하는 LLM

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/llama/06. autorag
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/llama/06. autorag

# %% [markdown]
# # 1. 모델 불러오기

# %%
modelName = "hyokwan/hkcode-solar-youtube-merged"
revision= "main"

config = AutoConfig.from_pretrained(modelName, revision=revision)
model = AutoModelForCausalLM.from_pretrained(modelName, revision=revision, torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(modelName, revision=revision)
print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/734 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/154 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=2)
#     (layers): ModuleList(
#       (0-47): 48 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %% [markdown]
# # 2. 문서 불러오기

# %%
sourceName = "secure_repo.pdf"

# %%
loader = PyPDFLoader(f'./pdfs/{sourceName}')
documents = loader.load()

# %% [markdown]
# # 3. 문서 분리(조각)

# %%
output = []
# text 정제
for page in documents:
    text = page.page_content
    output.append(text)

doc_chunks = []
for line in output:
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=500, # 최대 청크 길이
        separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""], #  텍스트를 청크로 분할하는 데 사용되는 문자 목록
        chunk_overlap=100, # 인접한 청크 간에 중복되는 문자 수
    )
    chunks = text_splitter.split_text(line)
    for i, chunk in enumerate(chunks):
        doc = Document(
            page_content=chunk, metadata={ "source": f"{sourceName}", "page": i}
        )
        doc_chunks.append(doc)

# %% [markdown]
# # 4. 임베딩 & 저장

# %%
# HuggingFaceEmbeddings 클래스를 사용하여 임베딩 모델 로드
embed_model = HuggingFaceEmbeddings(
    model_name="jhgan/ko-sroberta-nli"  # 한국어 문장 임베딩 모델
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/744 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Chroma 데이터베이스 디렉토리 및 컬렉션 이름 설정
persist_directory = "./chromadb"
collection_name = "hkcode_documents"

# 기존의 Chroma 인덱스를 로드하거나 없으면 새로 생성
try:
    index = Chroma(
        embedding_function=embed_model,
        persist_directory=persist_directory,
        collection_name=collection_name
    )
    # 컬렉션이 존재하면 문서 추가
    index.add_documents(doc_chunks)
except Exception as e:
    print(f"Error loading collection: {e}")
    # 컬렉션이 없으면 새로 생성하여 문서 추가
    index = Chroma.from_documents(
        documents=doc_chunks,
        embedding=embed_model,
        persist_directory=persist_directory,
        collection_name=collection_name
    )

# 변경된 내용을 디스크에 저장
index.persist()

# 검색기를 생성하여 유사도 검색 수행
retriever = index.as_retriever(search_kwargs={"k": 1})  # 검색 결과 상위 1개 반환
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %% [markdown]
# # 5. llm rag 파이프라인 생성

# %%
# 모델 설정을 로드하여 GenerationConfig 객체 생성
gen_cfg = GenerationConfig.from_pretrained(modelName)
# 생성 설정 세부 조정
gen_cfg.max_new_tokens = 1024  # 생성할 최대 토큰 수
gen_cfg.temperature = 0.0000001  # 텍스트 생성의 무작위성을 낮추는 온도 설정
gen_cfg.return_full_text = True  # 생성된 텍스트 전체 반환
gen_cfg.do_sample = True  # 샘플링을 통해 텍스트 생성
gen_cfg.repetition_penalty = 1.11  # 반복 페널티 설정

# HuggingFace의 파이프라인을 사용하여 텍스트 생성 파이프라인 생성
pipe = pipeline(
    task="text-generation",  # 파이프라인 작업 유형 설정
    model=model,  # 사전 훈련된 언어 모델
    tokenizer=tokenizer,  # 모델에 맞는 토크나이저
    generation_config=gen_cfg,  # 생성 설정 적용
    device=0  # 사용할 디바이스 설정 (기본 GPU를 사용할 경우 0으로 설정)
)

# LangChain의 HuggingFacePipeline을 사용하여 LLM 객체 생성
llm = HuggingFacePipeline(pipeline=pipe)
# LLAMA 2 LLM에 권장되는 프롬프트 스타일을 사용합니다.
prompt_template = """
[INST] <>
You are a wise assistant. Answer questions accurately in Korean
<>
{context}

Question: {question} [/INST]
"""

# 프롬프트 템플릿을 생성합니다.
prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

# RetrievalQA 체인을 생성합니다.
Chain_pdf = RetrievalQA.from_chain_type(
    llm=llm,  # 사용할 LLM을 지정합니다.
    chain_type="stuff",  # 체인의 타입을 지정합니다.
    retriever=retriever,  # 문서를 검색할 때 사용할 retriever를 지정합니다.
    return_source_documents=True, #소스출서 확인 지정
    chain_type_kwargs={"prompt": prompt},  # 체인 타입에 대한 추가 인자를 지정합니다.
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   warn_deprecated(

# %%
def extract_text_after_inst(text):
    answer = text['result'].strip()
    marker = '[/INST]'
    start = answer.find(marker)
    if start != -1:
        # Extract text after the marker
        return answer[start + len(marker):].strip()
    else:
        # Return an empty string or a suitable message if marker not found
        return "Marker '[/INST]' not found in the answer."

# %%
# 질의 내용 설정
query = "스마트금융과 주요 교과목은?"

# 질의에 대한 답변을 생성합니다.
result = Chain_pdf.invoke(query)
result
# Out:
# {'query': '스마트금융과 주요 교과목은?',
#  'result': '\n[INST] <>\nYou are a wise assistant. Answer questions accurately in Korean\n<>\n<하이테크과정 학과>\n학과 내용\n스마트금융\n☎02-2186-5861▪ 금융과 소프트웨어 기술을 융합한 핀테크 산업 분야의 실무형 개발자 양성\n▪ (주요교과목 ) 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발\n▪ (취득가능자격증 ) 정보처리기사 , 정보처리산업기사 , 리눅스마스터 , SQLD, OCJP, OCP\n▪ (취업분야 ) 데이터분석 기업, 소프트웨어 개발업체 , 블록체인 소프트웨어 개발업체 등\n사이버보안\n\nQuestion: 스마트금융과 주요 교과목은? [/INST]\n\nAnswer: 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발',
#  'source_documents': [Document(page_content='<하이테크과정 학과>\n학과 내용\n스마트금융\n☎02-2186-5861▪ 금융과 소프트웨어 기술을 융합한 핀테크 산업 분야의 실무형 개발자 양성\n▪ (주요교과목 ) 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발\n▪ (취득가능자격증 ) 정보처리기사 , 정보처리산업기사 , 리눅스마스터 , SQLD, OCJP, OCP\n▪ (취업분야 ) 데이터분석 기업, 소프트웨어 개발업체 , 블록체인 소프트웨어 개발업체 등\n사이버보안', metadata={'page': 1, 'source': '한국폴리텍대학_강서캠퍼스_모집요강.pdf'})]}

# %%
# 질의 내용 설정
query = "한국폴리텍대학 스마트금융과는 어떤걸 배워?"

# 질의에 대한 답변을 생성합니다.
result = Chain_pdf.invoke(query)
result
# Out:
# {'query': '한국폴리텍대학 스마트금융과는 어떤걸 배워?',
#  'result': '\n[INST] <>\nYou are a wise assistant. Answer questions accurately in Korean\n<>\n<하이테크과정 학과>\n학과 내용\n스마트금융\n☎02-2186-5861▪ 금융과 소프트웨어 기술을 융합한 핀테크 산업 분야의 실무형 개발자 양성\n▪ (주요교과목 ) 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발\n▪ (취득가능자격증 ) 정보처리기사 , 정보처리산업기사 , 리눅스마스터 , SQLD, OCJP, OCP\n▪ (취업분야 ) 데이터분석 기업, 소프트웨어 개발업체 , 블록체인 소프트웨어 개발업체 등\n사이버보안\n\nQuestion: 한국폴리텍대학 스마트금융과는 어떤걸 배워? [/INST]\n\nAnswer: 매년 업체에서 요구하는 기술은 변할수 있지만 기본적으로는 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발을 배운다.',
#  'source_documents': [Document(page_content='<하이테크과정 학과>\n학과 내용\n스마트금융\n☎02-2186-5861▪ 금융과 소프트웨어 기술을 융합한 핀테크 산업 분야의 실무형 개발자 양성\n▪ (주요교과목 ) 빅데이터 분석, 블록체인 개발, 금융데이터 분석, 웹 어플리케이션 개발\n▪ (취득가능자격증 ) 정보처리기사 , 정보처리산업기사 , 리눅스마스터 , SQLD, OCJP, OCP\n▪ (취업분야 ) 데이터분석 기업, 소프트웨어 개발업체 , 블록체인 소프트웨어 개발업체 등\n사이버보안', metadata={'page': 1, 'source': '한국폴리텍대학_강서캠퍼스_모집요강.pdf'})]}

# %%
# 질의 내용 설정
query = "불충분한 세션 만료 점검 내용은?"

# 질의에 대한 답변을 생성합니다.
result = Chain_pdf.invoke(query)
result
# Out:
# {'query': '불충분한 세션 만료 점검 내용은?',
#  'result': '\n[INST] <>\nYou are a wise assistant. Answer questions accurately in Korean\n<>\n참고※ 세션 타임아웃  시간 범위 : 세션 타임아웃  시간은 타 항목을 참고(N-06 5분 이하, \nU-15 10분 이하) \n점검대상 및 판단기준\n대상 /square6사용자와 세션 통신을 지원하는 제어시스템 구성요소 \n판단기준양호: 사용자 통신 세션 구간에서 타임아웃 기능이 설정된 경우\n취약: 사용자 통신 세션 구간에서 타임아웃 기능이 설정되지 않은 경우\n조치방법사용자 통신 세션 구간에서 일정 시간 입력이 없는 경우 자동으로 세션을 종료하는 \n세션 타임아웃 기능 설정 또는 개발변경\n점검 및 조치 사례\nStep 1) 점검 대상 장비에서 허용하는 세션 통신을 모두 식별하고, 식별된 세션에서 타임아웃 \n기능이 설정되어 있는지 확인\n[그림] 타임아웃  설정 화면 예시\nStep 2) Step 1에서 확인된 설정과 같이 실제로 타임아웃이 이 루어지는지 확인\n조치 시 \n영향일반적인 경우 영향 없음\n\x17\x1c\x19\n\nQuestion: 불충분한 세션 만료 점검 내용은? [/INST]\n\nAnswer: 영향 없음',
#  'source_documents': [Document(page_content='참고※ 세션 타임아웃  시간 범위 : 세션 타임아웃  시간은 타 항목을 참고(N-06 5분 이하, \nU-15 10분 이하) \n점검대상 및 판단기준\n대상 /square6사용자와 세션 통신을 지원하는 제어시스템 구성요소 \n판단기준양호: 사용자 통신 세션 구간에서 타임아웃 기능이 설정된 경우\n취약: 사용자 통신 세션 구간에서 타임아웃 기능이 설정되지 않은 경우\n조치방법사용자 통신 세션 구간에서 일정 시간 입력이 없는 경우 자동으로 세션을 종료하는 \n세션 타임아웃 기능 설정 또는 개발변경\n점검 및 조치 사례\nStep 1) 점검 대상 장비에서 허용하는 세션 통신을 모두 식별하고, 식별된 세션에서 타임아웃 \n기능이 설정되어 있는지 확인\n[그림] 타임아웃  설정 화면 예시\nStep 2) Step 1에서 확인된 설정과 같이 실제로 타임아웃이 이 루어지는지 확인\n조치 시 \n영향일반적인 경우 영향 없음\n\x17\x1c\x19', metadata={'page': 1, 'source': 'secure_repo.pdf'})]}

# %%
answer2 = extract_text_after_inst(result)
print(answer2)
# Out:
# Answer: 영향 없음

# %%
result
# Out:
# {'query': '불충분한 세션 만료 점검 내용은?',
#  'result': '\n[INST] <>\nYou are a wise assistant. Answer questions accurately in Korean\n<>\n참고※ 세션 타임아웃  시간 범위 : 세션 타임아웃  시간은 타 항목을 참고(N-06 5분 이하, \nU-15 10분 이하) \n점검대상 및 판단기준\n대상 /square6사용자와 세션 통신을 지원하는 제어시스템 구성요소 \n판단기준양호: 사용자 통신 세션 구간에서 타임아웃 기능이 설정된 경우\n취약: 사용자 통신 세션 구간에서 타임아웃 기능이 설정되지 않은 경우\n조치방법사용자 통신 세션 구간에서 일정 시간 입력이 없는 경우 자동으로 세션을 종료하는 \n세션 타임아웃 기능 설정 또는 개발변경\n점검 및 조치 사례\nStep 1) 점검 대상 장비에서 허용하는 세션 통신을 모두 식별하고, 식별된 세션에서 타임아웃 \n기능이 설정되어 있는지 확인\n[그림] 타임아웃  설정 화면 예시\nStep 2) Step 1에서 확인된 설정과 같이 실제로 타임아웃이 이 루어지는지 확인\n조치 시 \n영향일반적인 경우 영향 없음\n\x17\x1c\x19\n\nQuestion: 불충분한 세션 만료 점검 내용은? [/INST]\n\nAnswer: 영향 없음',
#  'source_documents': [Document(page_content='참고※ 세션 타임아웃  시간 범위 : 세션 타임아웃  시간은 타 항목을 참고(N-06 5분 이하, \nU-15 10분 이하) \n점검대상 및 판단기준\n대상 /square6사용자와 세션 통신을 지원하는 제어시스템 구성요소 \n판단기준양호: 사용자 통신 세션 구간에서 타임아웃 기능이 설정된 경우\n취약: 사용자 통신 세션 구간에서 타임아웃 기능이 설정되지 않은 경우\n조치방법사용자 통신 세션 구간에서 일정 시간 입력이 없는 경우 자동으로 세션을 종료하는 \n세션 타임아웃 기능 설정 또는 개발변경\n점검 및 조치 사례\nStep 1) 점검 대상 장비에서 허용하는 세션 통신을 모두 식별하고, 식별된 세션에서 타임아웃 \n기능이 설정되어 있는지 확인\n[그림] 타임아웃  설정 화면 예시\nStep 2) Step 1에서 확인된 설정과 같이 실제로 타임아웃이 이 루어지는지 확인\n조치 시 \n영향일반적인 경우 영향 없음\n\x17\x1c\x19', metadata={'page': 1, 'source': 'secure_repo.pdf'})]}

# %% [markdown]
# ### API 서버생성

# %%
from fastapi import FastAPI
import uvicorn
from pydantic import BaseModel

# %%
app=FastAPI(
    title="Python hkcode Assistent",
    version="1.0",
    decsription="API Server"
)

# %%
from fastapi.middleware.cors import CORSMiddleware
origins = ["*"]

# CORS 미들웨어 추가
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # 모든 origin 허용
    allow_credentials=True,
    allow_methods=["GET", "POST", "PUT", "DELETE"],
    allow_headers=["*"],
)

# %%
# FastAPI 연계 확인
class Input(BaseModel):
    input : str

# %%
@app.post("/predict", status_code=200)
async def predictDl(x: Input):
    print(x)
    prompt = x.input
    result = Chain_pdf.invoke(prompt)
    resul2 = extract_text_after_inst(result)
    return {"prediction":resul2}
@app.get("/")
async def root():
    return {"message":"onine"}

# %%
# if __name__=="__main__":
#     uvicorn.run(app,host="localhost",port=8000)

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

auth_token = "2hN39uPNEVwsHR4UMPoPQpGTI21_3eQv6mRq5YK8zjdv9Es5v"
ngrok.set_auth_token(auth_token)
ngrokTunnel = ngrok.connect(8000)
print("공용 URL", ngrokTunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# 공용 URL https://dea3-34-142-175-31.ngrok-free.app
# INFO:     Started server process [1618]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     58.143.148.41:0 - "OPTIONS /predict HTTP/1.1" 200 OK
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# input='한국폴리텍대학 스마트금융과는 어떤걸 배워?'
# INFO:     58.143.148.41:0 - "POST /predict HTTP/1.1" 200 OK
# input='한국폴리텍대학 스마트금융과는 어떤걸 배워?'
# INFO:     58.143.148.41:0 - "POST /predict HTTP/1.1" 200 OK
# input='한국폴리텍대학 스마트금융과는 전화번호는?'
# INFO:     58.143.148.41:0 - "POST /predict HTTP/1.1" 200 OK
# input='한국폴리텍대학 스마트금융과 전화번호는?'
# INFO:     58.143.148.41:0 - "POST /predict HTTP/1.1" 200 OK
# WARNING:pyngrok.process.ngrok:t=2024-06-23T03:08:27+0000 lvl=warn msg="Stopping forwarder" name=http-8000-e4a417e5-d27f-43ff-b789-8b9fba2ef0e3 acceptErr="failed to accept connection: Listener closed"
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1618]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-48025f376036> in <cell line: 10>()
#       8 print("공용 URL", ngrokTunnel.public_url)
#       9 nest_asyncio.apply()
# ---> 10 uvicorn.run(app, port=8000)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/main.py in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     575             Multiprocess(config, target=server.run, sockets=[sock]).run()
#     576         else:
# --> 577             server.run()
#     578     finally:
#     579         if config.uds and os.path.exists(config.uds):
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in run(self, sockets)
#      63     def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64         self.config.setup_event_loop()
# ---> 65         return asyncio.run(self.serve(sockets=sockets))
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in _run_once(self)
#     131
#     132                 try:
# --> 133                     handle._run()
#     134                 finally:
#     135                     # restore the current task
#
# /usr/lib/python3.10/asyncio/events.py in _run(self)
#      78     def _run(self):
#      79         try:
# ---> 80             self._context.run(self._callback, *self._args)
#      81         except (SystemExit, KeyboardInterrupt):
#      82             raise
#
# /usr/lib/python3.10/asyncio/tasks.py in __wakeup(self, future)
#     313             # instead of `__next__()`, which is slower for futures
#     314             # that return non-generator iterators from their `__iter__`.
# --> 315             self.__step()
#     316         self = None  # Needed to break cycles when an exception occurs.
#     317
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in serve(self, sockets)
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68         with self.capture_signals():
#      69             await self._serve(sockets)
#      70
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in capture_signals(self)
#     326         # done LIFO, see https://stackoverflow.com/questions/48434964
#     327         for captured_signal in reversed(self._captured_signals):
# --> 328             signal.raise_signal(captured_signal)
#     329
#     330     def handle_exit(self, sig: int, frame: FrameType | None) -> None:
#
# KeyboardInterrupt:
